# %% [markdown]
# # Allen data download and visualization
#
# ## electrophysiology and morpology data from allen brain data portal
#
# ### Purpose of this notebook
#
# 1. download fresh data from allen data portal.
# 1. extract necessary feature(deleting columns)
# 1. cre reporter status tagging to binary(E vs I)
# 1. saving csv file.
# 1. visualizing some features for verification
#
# ### Requirements for this notebook
# * __allensdk__ for python2.7
# * [Reference notebook](http://alleninstitute.github.io/AllenSDK/_static/examples/nb/cell_types.html)

# %%
from allensdk.core.cell_types_cache import CellTypesCache
from allensdk.api.queries.cell_types_api import CellTypesApi
from allensdk.core.cell_types_cache import ReporterStatus as RS
import pandas as pd

# %%
ctc = CellTypesCache(manifest_file='./Allen_meta/manifest.json')

# %%
# all cells
cells = ctc.get_cells()
print("All cells: %d" % len(cells))
# Out:
# All cells: 2228

# %%
ephys_features = ctc.get_ephys_features()
ef_df = pd.DataFrame(ephys_features)
print(len(ef_df))
ef_df.head()
# Out:
# 2228
#    adaptation     avg_isi  electrode_0_pa  f_i_curve_slope  \
# 0         NaN  134.700000       22.697498     8.335459e-02
# 1         NaN         NaN      -24.887498    -3.913630e-19
# 2    0.009770   39.044800      -46.765002     5.267857e-01
# 3   -0.007898  117.816429        5.996250     1.542553e-01
# 4    0.022842   68.321429       14.910000     1.714041e-01
#
#    fast_trough_t_long_square  fast_trough_t_ramp  fast_trough_t_short_square  \
# 0                   1.187680           13.295200                    1.025916
# 1                   1.099840           20.650105                    1.025460
# 2                   1.157840            2.551310                    1.025387
# 3                   1.989165            9.572025                    1.028733
# 4                   1.081980            2.462880                    1.025620
#
#    fast_trough_v_long_square  fast_trough_v_ramp  fast_trough_v_short_square  \
# 0                 -56.375004          -57.385420                  -57.431251
# 1                 -54.000000          -54.828129                  -54.656254
# 2                 -59.500000          -58.234378                  -59.940975
# 3                 -47.531250          -50.359375                  -65.500000
# 4                 -48.437504          -46.520837                  -51.406253
#
#      ...      trough_t_ramp  trough_t_short_square  trough_v_long_square  \
# 0    ...          13.295680               1.134780            -56.593754
# 1    ...          20.650735               1.160940            -55.406254
# 2    ...           2.551960               1.089851            -60.062500
# 3    ...           9.576308               1.423229            -49.406254
# 4    ...           2.490433               1.479690            -53.000004
#
#    trough_v_ramp  trough_v_short_square  \
# 0     -57.739586             -74.143753
# 1     -55.242191             -73.500000
# 2     -58.570314             -61.371531
# 3     -52.718752             -75.273443
# 4     -54.645837             -64.250003
#
#    upstroke_downstroke_ratio_long_square  upstroke_downstroke_ratio_ramp  \
# 0                               3.029695                        3.061646
# 1                               2.441895                        2.245653
# 2                               2.023762                        2.162878
# 3                               3.105931                        3.491663
# 4                               3.285760                        3.363504
#
#    upstroke_downstroke_ratio_short_square  vm_for_sag      vrest
# 0                                2.969821  -80.468750 -73.553391
# 1                                2.231575  -84.406258 -73.056595
# 2                                2.006406  -93.375008 -60.277321
# 3                                1.733896  -87.656250 -75.205559
# 4                                4.234701  -81.625008 -63.474991
#
# [5 rows x 55 columns]

# %%
cell_index = { c['id']: c for c in cells }
reporter_status = [cell_index[cid]['reporter_status'] for cid in ef_df['specimen_id']]
tg_line = [cell_index[cid]['transgenic_line'] for cid in ef_df['specimen_id']]
hemisphere = [cell_index[cid]['hemisphere'] for cid in ef_df['specimen_id']]
ef_df['transgenic_line'] = pd.Series(tg_line, index=ef_df.index)
ef_df.head()
# Out:
#    adaptation     avg_isi  electrode_0_pa  f_i_curve_slope  \
# 0         NaN  134.700000       22.697498     8.335459e-02
# 1         NaN         NaN      -24.887498    -3.913630e-19
# 2    0.009770   39.044800      -46.765002     5.267857e-01
# 3   -0.007898  117.816429        5.996250     1.542553e-01
# 4    0.022842   68.321429       14.910000     1.714041e-01
#
#    fast_trough_t_long_square  fast_trough_t_ramp  fast_trough_t_short_square  \
# 0                   1.187680           13.295200                    1.025916
# 1                   1.099840           20.650105                    1.025460
# 2                   1.157840            2.551310                    1.025387
# 3                   1.989165            9.572025                    1.028733
# 4                   1.081980            2.462880                    1.025620
#
#    fast_trough_v_long_square  fast_trough_v_ramp  fast_trough_v_short_square  \
# 0                 -56.375004          -57.385420                  -57.431251
# 1                 -54.000000          -54.828129                  -54.656254
# 2                 -59.500000          -58.234378                  -59.940975
# 3                 -47.531250          -50.359375                  -65.500000
# 4                 -48.437504          -46.520837                  -51.406253
#
#          ...         trough_t_short_square  trough_v_long_square  \
# 0        ...                      1.134780            -56.593754
# 1        ...                      1.160940            -55.406254
# 2        ...                      1.089851            -60.062500
# 3        ...                      1.423229            -49.406254
# 4        ...                      1.479690            -53.000004
#
#    trough_v_ramp  trough_v_short_square  \
# 0     -57.739586             -74.143753
# 1     -55.242191             -73.500000
# 2     -58.570314             -61.371531
# 3     -52.718752             -75.273443
# 4     -54.645837             -64.250003
#
#    upstroke_downstroke_ratio_long_square  upstroke_downstroke_ratio_ramp  \
# 0                               3.029695                        3.061646
# 1                               2.441895                        2.245653
# 2                               2.023762                        2.162878
# 3                               3.105931                        3.491663
# 4                               3.285760                        3.363504
#
#    upstroke_downstroke_ratio_short_square  vm_for_sag      vrest  \
# 0                                2.969821  -80.468750 -73.553391
# 1                                2.231575  -84.406258 -73.056595
# 2                                2.006406  -93.375008 -60.277321
# 3                                1.733896  -87.656250 -75.205559
# 4                                4.234701  -81.625008 -63.474991
#
#     transgenic_line
# 0              None
# 1              None
# 2  Ndnf-IRES2-dgCre
# 3   Htr3a-Cre_NO152
# 4    Scnn1a-Tg3-Cre
#
# [5 rows x 56 columns]

# %%
ef_df['reporter_status'] = pd.Series(reporter_status, index=ef_df.index)
ef_df.head()
# Out:
#    adaptation     avg_isi  electrode_0_pa  f_i_curve_slope  \
# 0         NaN  134.700000       22.697498     8.335459e-02
# 1         NaN         NaN      -24.887498    -3.913630e-19
# 2    0.009770   39.044800      -46.765002     5.267857e-01
# 3   -0.007898  117.816429        5.996250     1.542553e-01
# 4    0.022842   68.321429       14.910000     1.714041e-01
#
#    fast_trough_t_long_square  fast_trough_t_ramp  fast_trough_t_short_square  \
# 0                   1.187680           13.295200                    1.025916
# 1                   1.099840           20.650105                    1.025460
# 2                   1.157840            2.551310                    1.025387
# 3                   1.989165            9.572025                    1.028733
# 4                   1.081980            2.462880                    1.025620
#
#    fast_trough_v_long_square  fast_trough_v_ramp  fast_trough_v_short_square  \
# 0                 -56.375004          -57.385420                  -57.431251
# 1                 -54.000000          -54.828129                  -54.656254
# 2                 -59.500000          -58.234378                  -59.940975
# 3                 -47.531250          -50.359375                  -65.500000
# 4                 -48.437504          -46.520837                  -51.406253
#
#         ...         trough_v_long_square  trough_v_ramp  \
# 0       ...                   -56.593754     -57.739586
# 1       ...                   -55.406254     -55.242191
# 2       ...                   -60.062500     -58.570314
# 3       ...                   -49.406254     -52.718752
# 4       ...                   -53.000004     -54.645837
#
#    trough_v_short_square  upstroke_downstroke_ratio_long_square  \
# 0             -74.143753                               3.029695
# 1             -73.500000                               2.441895
# 2             -61.371531                               2.023762
# 3             -75.273443                               3.105931
# 4             -64.250003                               3.285760
#
#    upstroke_downstroke_ratio_ramp  upstroke_downstroke_ratio_short_square  \
# 0                        3.061646                                2.969821
# 1                        2.245653                                2.231575
# 2                        2.162878                                2.006406
# 3                        3.491663                                1.733896
# 4                        3.363504                                4.234701
#
#    vm_for_sag      vrest   transgenic_line  reporter_status
# 0  -80.468750 -73.553391              None   not applicable
# 1  -84.406258 -73.056595              None   not applicable
# 2  -93.375008 -60.277321  Ndnf-IRES2-dgCre         positive
# 3  -87.656250 -75.205559   Htr3a-Cre_NO152         positive
# 4  -81.625008 -63.474991    Scnn1a-Tg3-Cre         positive
#
# [5 rows x 57 columns]

# %%
ef_df['hemisphere'] = pd.Series(hemisphere, index = ef_df.index)
ef_df.head()
# Out:
#    adaptation     avg_isi  electrode_0_pa  f_i_curve_slope  \
# 0         NaN  134.700000       22.697498     8.335459e-02
# 1         NaN         NaN      -24.887498    -3.913630e-19
# 2    0.009770   39.044800      -46.765002     5.267857e-01
# 3   -0.007898  117.816429        5.996250     1.542553e-01
# 4    0.022842   68.321429       14.910000     1.714041e-01
#
#    fast_trough_t_long_square  fast_trough_t_ramp  fast_trough_t_short_square  \
# 0                   1.187680           13.295200                    1.025916
# 1                   1.099840           20.650105                    1.025460
# 2                   1.157840            2.551310                    1.025387
# 3                   1.989165            9.572025                    1.028733
# 4                   1.081980            2.462880                    1.025620
#
#    fast_trough_v_long_square  fast_trough_v_ramp  fast_trough_v_short_square  \
# 0                 -56.375004          -57.385420                  -57.431251
# 1                 -54.000000          -54.828129                  -54.656254
# 2                 -59.500000          -58.234378                  -59.940975
# 3                 -47.531250          -50.359375                  -65.500000
# 4                 -48.437504          -46.520837                  -51.406253
#
#       ...      trough_v_ramp  trough_v_short_square  \
# 0     ...         -57.739586             -74.143753
# 1     ...         -55.242191             -73.500000
# 2     ...         -58.570314             -61.371531
# 3     ...         -52.718752             -75.273443
# 4     ...         -54.645837             -64.250003
#
#    upstroke_downstroke_ratio_long_square  upstroke_downstroke_ratio_ramp  \
# 0                               3.029695                        3.061646
# 1                               2.441895                        2.245653
# 2                               2.023762                        2.162878
# 3                               3.105931                        3.491663
# 4                               3.285760                        3.363504
#
#    upstroke_downstroke_ratio_short_square  vm_for_sag      vrest  \
# 0                                2.969821  -80.468750 -73.553391
# 1                                2.231575  -84.406258 -73.056595
# 2                                2.006406  -93.375008 -60.277321
# 3                                1.733896  -87.656250 -75.205559
# 4                                4.234701  -81.625008 -63.474991
#
#     transgenic_line  reporter_status  hemisphere
# 0              None   not applicable        left
# 1              None   not applicable       right
# 2  Ndnf-IRES2-dgCre         positive       right
# 3   Htr3a-Cre_NO152         positive        left
# 4    Scnn1a-Tg3-Cre         positive        left
#
# [5 rows x 58 columns]

# %%
ef_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2228 entries, 0 to 2227
# Data columns (total 58 columns):
# adaptation                                1915 non-null float64
# avg_isi                                   2085 non-null float64
# electrode_0_pa                            2219 non-null float64
# f_i_curve_slope                           2228 non-null float64
# fast_trough_t_long_square                 2228 non-null float64
# fast_trough_t_ramp                        2169 non-null float64
# fast_trough_t_short_square                2228 non-null float64
# fast_trough_v_long_square                 2228 non-null float64
# fast_trough_v_ramp                        2169 non-null float64
# fast_trough_v_short_square                2228 non-null float64
# has_burst                                 2228 non-null bool
# has_delay                                 2228 non-null bool
# has_pause                                 2228 non-null bool
# id                                        2228 non-null int64
# input_resistance_mohm                     2228 non-null float64
# latency                                   2228 non-null float64
# peak_t_long_square                        2228 non-null float64
# peak_t_ramp                               2169 non-null float64
# peak_t_short_square                       2228 non-null float64
# peak_v_long_square                        2228 non-null float64
# peak_v_ramp                               2169 non-null float64
# peak_v_short_square                       2228 non-null float64
# rheobase_sweep_id                         2228 non-null int64
# rheobase_sweep_number                     2228 non-null int64
# ri                                        2228 non-null float64
# sag                                       2228 non-null float64
# seal_gohm                                 2228 non-null float64
# slow_trough_t_long_square                 1081 non-null float64
# slow_trough_t_ramp                        1449 non-null float64
# slow_trough_t_short_square                887 non-null float64
# slow_trough_v_long_square                 1081 non-null float64
# slow_trough_v_ramp                        1449 non-null float64
# slow_trough_v_short_square                887 non-null float64
# specimen_id                               2228 non-null int64
# threshold_i_long_square                   2228 non-null float64
# threshold_i_ramp                          2169 non-null float64
# threshold_i_short_square                  2228 non-null float64
# threshold_t_long_square                   2228 non-null float64
# threshold_t_ramp                          2169 non-null float64
# threshold_t_short_square                  2228 non-null float64
# threshold_v_long_square                   2228 non-null float64
# threshold_v_ramp                          2169 non-null float64
# threshold_v_short_square                  2228 non-null float64
# thumbnail_sweep_id                        2228 non-null int64
# trough_t_long_square                      2228 non-null float64
# trough_t_ramp                             2169 non-null float64
# trough_t_short_square                     2228 non-null float64
# trough_v_long_square                      2228 non-null float64
# trough_v_ramp                             2169 non-null float64
# trough_v_short_square                     2228 non-null float64
# upstroke_downstroke_ratio_long_square     2228 non-null float64
# upstroke_downstroke_ratio_ramp            2169 non-null float64
# upstroke_downstroke_ratio_short_square    2228 non-null float64
# vm_for_sag                                2228 non-null float64
# vrest                                     2228 non-null float64
# transgenic_line                           1918 non-null object
# reporter_status                           2228 non-null object
# hemisphere                                2228 non-null object
# dtypes: bool(3), float64(47), int64(5), object(3)
# memory usage: 963.9+ KB

# %%
no_need_features = ['electrode_0_pa', 'has_burst', 'has_delay', 'has_pause', 'id', 
                    'rheobase_sweep_id', 'rheobase_sweep_number', 'seal_gohm', 'specimen_id',
                   'thumbnail_sweep_id', 'slow_trough_t_long_square', 'slow_trough_t_ramp', 
                   'slow_trough_v_long_square', 'slow_trough_v_ramp']

# %%
ef_df_extracted = ef_df.drop(no_need_features, axis=1)
ef_df_extracted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2228 entries, 0 to 2227
# Data columns (total 44 columns):
# adaptation                                1915 non-null float64
# avg_isi                                   2085 non-null float64
# f_i_curve_slope                           2228 non-null float64
# fast_trough_t_long_square                 2228 non-null float64
# fast_trough_t_ramp                        2169 non-null float64
# fast_trough_t_short_square                2228 non-null float64
# fast_trough_v_long_square                 2228 non-null float64
# fast_trough_v_ramp                        2169 non-null float64
# fast_trough_v_short_square                2228 non-null float64
# input_resistance_mohm                     2228 non-null float64
# latency                                   2228 non-null float64
# peak_t_long_square                        2228 non-null float64
# peak_t_ramp                               2169 non-null float64
# peak_t_short_square                       2228 non-null float64
# peak_v_long_square                        2228 non-null float64
# peak_v_ramp                               2169 non-null float64
# peak_v_short_square                       2228 non-null float64
# ri                                        2228 non-null float64
# sag                                       2228 non-null float64
# slow_trough_t_short_square                887 non-null float64
# slow_trough_v_short_square                887 non-null float64
# threshold_i_long_square                   2228 non-null float64
# threshold_i_ramp                          2169 non-null float64
# threshold_i_short_square                  2228 non-null float64
# threshold_t_long_square                   2228 non-null float64
# threshold_t_ramp                          2169 non-null float64
# threshold_t_short_square                  2228 non-null float64
# threshold_v_long_square                   2228 non-null float64
# threshold_v_ramp                          2169 non-null float64
# threshold_v_short_square                  2228 non-null float64
# trough_t_long_square                      2228 non-null float64
# trough_t_ramp                             2169 non-null float64
# trough_t_short_square                     2228 non-null float64
# trough_v_long_square                      2228 non-null float64
# trough_v_ramp                             2169 non-null float64
# trough_v_short_square                     2228 non-null float64
# upstroke_downstroke_ratio_long_square     2228 non-null float64
# upstroke_downstroke_ratio_ramp            2169 non-null float64
# upstroke_downstroke_ratio_short_square    2228 non-null float64
# vm_for_sag                                2228 non-null float64
# vrest                                     2228 non-null float64
# transgenic_line                           1918 non-null object
# reporter_status                           2228 non-null object
# hemisphere                                2228 non-null object
# dtypes: float64(41), object(3)
# memory usage: 765.9+ KB

# %%
ef_df_extracted['height'] = ef_df_extracted['peak_v_short_square'] -ef_df_extracted['fast_trough_v_short_square']
ef_df_extracted['firing_rate'] = (1/ef_df_extracted['avg_isi'])*1000
ef_df_extracted.head()
# Out:
#    adaptation     avg_isi  f_i_curve_slope  fast_trough_t_long_square  \
# 0         NaN  134.700000     8.335459e-02                   1.187680
# 1         NaN         NaN    -3.913630e-19                   1.099840
# 2    0.009770   39.044800     5.267857e-01                   1.157840
# 3   -0.007898  117.816429     1.542553e-01                   1.989165
# 4    0.022842   68.321429     1.714041e-01                   1.081980
#
#    fast_trough_t_ramp  fast_trough_t_short_square  fast_trough_v_long_square  \
# 0           13.295200                    1.025916                 -56.375004
# 1           20.650105                    1.025460                 -54.000000
# 2            2.551310                    1.025387                 -59.500000
# 3            9.572025                    1.028733                 -47.531250
# 4            2.462880                    1.025620                 -48.437504
#
#    fast_trough_v_ramp  fast_trough_v_short_square  input_resistance_mohm  \
# 0          -57.385420                  -57.431251              54.894264
# 1          -54.828129                  -54.656254             103.684656
# 2          -58.234378                  -59.940975             224.580336
# 3          -50.359375                  -65.500000             151.193344
# 4          -46.520837                  -51.406253             171.530176
#
#       ...       upstroke_downstroke_ratio_long_square  \
# 0     ...                                    3.029695
# 1     ...                                    2.441895
# 2     ...                                    2.023762
# 3     ...                                    3.105931
# 4     ...                                    3.285760
#
#    upstroke_downstroke_ratio_ramp  upstroke_downstroke_ratio_short_square  \
# 0                        3.061646                                2.969821
# 1                        2.245653                                2.231575
# 2                        2.162878                                2.006406
# 3                        3.491663                                1.733896
# 4                        3.363504                                4.234701
#
#    vm_for_sag      vrest   transgenic_line  reporter_status  hemisphere  \
# 0  -80.468750 -73.553391              None   not applicable        left
# 1  -84.406258 -73.056595              None   not applicable       right
# 2  -93.375008 -60.277321  Ndnf-IRES2-dgCre         positive       right
# 3  -87.656250 -75.205559   Htr3a-Cre_NO152         positive        left
# 4  -81.625008 -63.474991    Scnn1a-Tg3-Cre         positive        left
#
#        height  firing_rate
# 0  105.506253     7.423905
# 1   91.312508          NaN
# 2   84.329864    25.611605
# 3   75.828125     8.487781
# 4   88.476567    14.636696
#
# [5 rows x 46 columns]

# %%
def dis_EI(cre_line): # labelling for excitory vs inbihitory cre line
    output = []
    for item in cre_line:
        if (item == 'Pvalb-IRES-Cre' or item == 'Sst-IRES-Cre' or
            item == 'Htr3a-Cre_NO152' or item == 'Vip-IRES-Cre' or
            item == 'Gad2-IRES-Cre' or item == 'Chat-IRES-Cre-neo' or
            item == 'Chrna2-Cre_OE25' or item == 'Nkx2-1-CreERT2'):
                output = output + ['Inhibitory']
        else:
            output = output + ['Excitatory']
    return output
ef_df_extracted['binary_neuron'] = pd.DataFrame(dis_EI(ef_df_extracted['transgenic_line']))
ef_df_extracted.tail()
# Out:
#       adaptation     avg_isi  f_i_curve_slope  fast_trough_t_long_square  \
# 2223    0.003986   20.891111         0.558727                   1.256315
# 2224    0.179194  245.906667         0.057143                   1.198760
# 2225    0.064075   98.066667         0.179114                   1.180315
# 2226    0.015452   52.414667         0.176210                   1.216980
# 2227    0.227778   72.460000         0.069643                   1.109160
#
#       fast_trough_t_ramp  fast_trough_t_short_square  \
# 2223           14.493233                    1.024111
# 2224            9.888127                    1.026348
# 2225            3.363480                    1.026457
# 2226            2.176593                    1.025509
# 2227            5.296718                    1.024698
#
#       fast_trough_v_long_square  fast_trough_v_ramp  \
# 2223                 -59.406254          -58.531254
# 2224                 -47.000000          -44.468754
# 2225                 -47.593754          -47.020835
# 2226                 -46.343750          -46.687503
# 2227                 -50.281254          -49.906253
#
#       fast_trough_v_short_square  input_resistance_mohm      ...        \
# 2223                  -61.912501             101.416240      ...
# 2224                  -47.493754              66.745424      ...
# 2225                  -52.979168             201.156832      ...
# 2226                  -50.450895             283.386752      ...
# 2227                  -52.937501             116.282496      ...
#
#       upstroke_downstroke_ratio_ramp  upstroke_downstroke_ratio_short_square  \
# 2223                        1.354347                                1.475020
# 2224                        3.817988                                4.980603
# 2225                        3.982813                                3.957265
# 2226                        3.000039                                2.261698
# 2227                        3.337449                                3.804038
#
#       vm_for_sag      vrest  transgenic_line  reporter_status  hemisphere  \
# 2223  -85.468758 -78.499512   Rorb-IRES2-Cre         negative        left
# 2224  -84.218758 -72.547661             None   not applicable        left
# 2225  -94.968750 -72.988518     Cux2-CreERT2         positive        left
# 2226  -98.875000 -59.984798     Vip-IRES-Cre         positive       right
# 2227  -82.343758 -69.373192     Cux2-CreERT2         positive       right
#
#          height  firing_rate  binary_neuron
# 2223  82.393752    47.867248     Excitatory
# 2224  93.737504     4.066584     Excitatory
# 2225  92.697920    10.197145     Excitatory
# 2226  61.995538    19.078629     Inhibitory
# 2227  97.135419    13.800718     Excitatory
#
# [5 rows x 47 columns]

# %%
ef_df_cre = ef_df_extracted[ef_df_extracted['reporter_status']=='positive']
len(ef_df_cre)
# Out:
# 1813

# %%
pd.DataFrame(ef_df_cre['transgenic_line'].value_counts())
# Out:
#                      transgenic_line
# Pvalb-IRES-Cre                   216
# Htr3a-Cre_NO152                  161
# Rorb-IRES2-Cre                   132
# Sst-IRES-Cre                     122
# Vip-IRES-Cre                      94
# Ndnf-IRES2-dgCre                  93
# Scnn1a-Tg3-Cre                    87
# Rbp4-Cre_KL100                    83
# Nr5a1-Cre                         82
# Cux2-CreERT2                      78
# Chrna2-Cre_OE25                   69
# Chat-IRES-Cre-neo                 67
# Ntsr1-Cre_GN220                   56
# Nos1-CreERT2                      54
# Ctgf-T2A-dgCre                    51
# Nkx2-1-CreERT2                    48
# Oxtr-T2A-Cre                      46
# Vipr2-IRES2-Cre                   42
# Scnn1a-Tg2-Cre                    42
# Tlx3-Cre_PL56                     40
# Sim1-Cre_KJ18                     32
# Esr2-IRES2-Cre                    28
# Gad2-IRES-Cre                     19
# Slc32a1-T2A-FlpO                  15
# Sst-IRES-FlpO                     13
# Pvalb-T2A-Dre                     12
# Glt25d2-Cre_NF107                 12
# Penk-IRES2-Cre-neo                 8
# Slc17a6-IRES-Cre                   3
# Pvalb-T2A-CreERT2                  2
# Pvalb-T2A-FlpO                     2
# Vipr2-IRES2-Cre-neo                1
# Esr2-IRES2-Cre-neo                 1
# PhiC31-neo                         1
# Gng7-Cre_KH71                      1

# %%
pd.DataFrame(ef_df_cre['binary_neuron'].value_counts())
# Out:
#             binary_neuron
# Excitatory           1017
# Inhibitory            796

# %% [markdown]
# ## Caution!!
#
# * Because the allen db updated the cell types, our current model is not match. We built our models in early 2018 (in Feb~Mar). So we don't want mess up models built, the data was not downloaded but just checked.
# * For current model, we keep using previous downloaded data(1802.. or ephys_data, cre_...csv)
