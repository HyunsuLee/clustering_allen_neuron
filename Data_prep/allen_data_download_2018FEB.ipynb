# %% [markdown]
# # Clustering neuron data
# ## electrophysiology and morpology data from allen brain data portal
#
# ### Purpose of this notebook
# 1. download fresh data from allen data portal.
# 1. extract necessary feature(deleting columns)
# 1. cre reporter status tagging to binary(E vs I)
# 1. saving csv file.
#
# ## This note was created 2018-FEB. If you rerun the cells, you'll get different results due allen database updated.
# ## New notebook can be checked [here](./allen_data_download_2018JUL.ipynb)

# %% [markdown]
# Requirements for this notebook
# * __allensdk__ for python2.7
# * [Reference notebook](http://alleninstitute.github.io/AllenSDK/_static/examples/nb/cell_types.html)

# %%
from allensdk.core.cell_types_cache import CellTypesCache
from allensdk.api.queries.cell_types_api import CellTypesApi
from allensdk.core.cell_types_cache import ReporterStatus as RS
import pandas as pd

# %%
ctc = CellTypesCache(manifest_file='cell_types/manifest.json')

# %%
# all cells
cells = ctc.get_cells()
print("All cells: %d" % len(cells))
# Out:
# All cells: 1337

# %%
ephys_features = ctc.get_ephys_features()
ef_df = pd.DataFrame(ephys_features)
print(len(ef_df))
ef_df.head()
# Out:
# 1337
#    adaptation     avg_isi  electrode_0_pa  f_i_curve_slope  \
# 0    0.093021   81.498750       -6.184375         0.205899
# 1    0.064384   76.283333       26.135000         0.195247
# 2         NaN         NaN       -4.600001         0.055443
# 3    0.048709  118.397143      -90.575616         0.307589
# 4    0.042215   81.394545       13.653750         0.162729
#
#    fast_trough_t_long_square  fast_trough_t_ramp  fast_trough_t_short_square  \
# 0                   1.126905            2.768700                    1.025464
# 1                   1.102660            4.005247                    1.024873
# 2                   1.104820            9.092507                    1.025024
# 3                   1.069770            7.203945                    1.024593
# 4                   1.089750            2.336427                    1.027302
#
#    fast_trough_v_long_square  fast_trough_v_ramp  fast_trough_v_short_square  \
# 0                 -51.187504          -50.328125                  -55.312504
# 1                 -48.718750          -49.875001                  -51.500004
# 2                 -48.093750          -49.541669                  -50.312503
# 3                 -45.968754          -49.093754                  -53.800002
# 4                 -48.906250          -51.083335                  -55.800002
#
#      ...      trough_t_ramp  trough_t_short_square  trough_v_long_square  \
# 0    ...           2.804613               1.333809            -56.531254
# 1    ...           4.005453               1.344913            -48.843754
# 2    ...           9.103360               1.197772            -49.531250
# 3    ...           7.204045               1.233473            -46.156254
# 4    ...           2.361778               1.691744            -52.093750
#
#    trough_v_ramp  trough_v_short_square  \
# 0     -56.812502             -69.306253
# 1     -50.093753             -67.416669
# 2     -49.968753             -75.656255
# 3     -49.218753             -66.318753
# 4     -57.614586             -73.337500
#
#    upstroke_downstroke_ratio_long_square  upstroke_downstroke_ratio_ramp  \
# 0                               3.904747                        4.131130
# 1                               4.231335                        4.299535
# 2                               2.154281                        1.486651
# 3                               2.026000                        1.827572
# 4                               4.208485                        4.274151
#
#    upstroke_downstroke_ratio_short_square  vm_for_sag      vrest
# 0                                3.899439  -85.156258 -68.233376
# 1                                3.939083  -78.593750 -66.085068
# 2                                2.400687  -87.156250 -75.141449
# 3                                1.818158  -82.406250 -65.503044
# 4                                4.096372  -99.093758 -72.174675
#
# [5 rows x 55 columns]

# %%
cell_index = { c['id']: c for c in cells }

# %%
reporter_status = [cell_index[cid]['reporter_status'] for cid in ef_df['specimen_id']]

# %%
tg_line = [cell_index[cid]['transgenic_line'] for cid in ef_df['specimen_id']]

# %%
hemisphere = [cell_index[cid]['hemisphere'] for cid in ef_df['specimen_id']]

# %%
ef_df['transgenic_line'] = pd.Series(tg_line, index=ef_df.index)
ef_df.head()
# Out:
#    adaptation     avg_isi  electrode_0_pa  f_i_curve_slope  \
# 0    0.093021   81.498750       -6.184375         0.205899
# 1    0.064384   76.283333       26.135000         0.195247
# 2         NaN         NaN       -4.600001         0.055443
# 3    0.048709  118.397143      -90.575616         0.307589
# 4    0.042215   81.394545       13.653750         0.162729
#
#    fast_trough_t_long_square  fast_trough_t_ramp  fast_trough_t_short_square  \
# 0                   1.126905            2.768700                    1.025464
# 1                   1.102660            4.005247                    1.024873
# 2                   1.104820            9.092507                    1.025024
# 3                   1.069770            7.203945                    1.024593
# 4                   1.089750            2.336427                    1.027302
#
#    fast_trough_v_long_square  fast_trough_v_ramp  fast_trough_v_short_square  \
# 0                 -51.187504          -50.328125                  -55.312504
# 1                 -48.718750          -49.875001                  -51.500004
# 2                 -48.093750          -49.541669                  -50.312503
# 3                 -45.968754          -49.093754                  -53.800002
# 4                 -48.906250          -51.083335                  -55.800002
#
#         ...         trough_t_short_square  trough_v_long_square  \
# 0       ...                      1.333809            -56.531254
# 1       ...                      1.344913            -48.843754
# 2       ...                      1.197772            -49.531250
# 3       ...                      1.233473            -46.156254
# 4       ...                      1.691744            -52.093750
#
#    trough_v_ramp  trough_v_short_square  \
# 0     -56.812502             -69.306253
# 1     -50.093753             -67.416669
# 2     -49.968753             -75.656255
# 3     -49.218753             -66.318753
# 4     -57.614586             -73.337500
#
#    upstroke_downstroke_ratio_long_square  upstroke_downstroke_ratio_ramp  \
# 0                               3.904747                        4.131130
# 1                               4.231335                        4.299535
# 2                               2.154281                        1.486651
# 3                               2.026000                        1.827572
# 4                               4.208485                        4.274151
#
#    upstroke_downstroke_ratio_short_square  vm_for_sag      vrest  \
# 0                                3.899439  -85.156258 -68.233376
# 1                                3.939083  -78.593750 -66.085068
# 2                                2.400687  -87.156250 -75.141449
# 3                                1.818158  -82.406250 -65.503044
# 4                                4.096372  -99.093758 -72.174675
#
#    transgenic_line
# 0     Cux2-CreERT2
# 1  Chrna2-Cre_OE25
# 2             None
# 3     Sst-IRES-Cre
# 4     Cux2-CreERT2
#
# [5 rows x 56 columns]

# %%
ef_df['reporter_status'] = pd.Series(reporter_status, index=ef_df.index)
ef_df.head()
# Out:
#    adaptation     avg_isi  electrode_0_pa  f_i_curve_slope  \
# 0    0.093021   81.498750       -6.184375         0.205899
# 1    0.064384   76.283333       26.135000         0.195247
# 2         NaN         NaN       -4.600001         0.055443
# 3    0.048709  118.397143      -90.575616         0.307589
# 4    0.042215   81.394545       13.653750         0.162729
#
#    fast_trough_t_long_square  fast_trough_t_ramp  fast_trough_t_short_square  \
# 0                   1.126905            2.768700                    1.025464
# 1                   1.102660            4.005247                    1.024873
# 2                   1.104820            9.092507                    1.025024
# 3                   1.069770            7.203945                    1.024593
# 4                   1.089750            2.336427                    1.027302
#
#    fast_trough_v_long_square  fast_trough_v_ramp  fast_trough_v_short_square  \
# 0                 -51.187504          -50.328125                  -55.312504
# 1                 -48.718750          -49.875001                  -51.500004
# 2                 -48.093750          -49.541669                  -50.312503
# 3                 -45.968754          -49.093754                  -53.800002
# 4                 -48.906250          -51.083335                  -55.800002
#
#            ...            trough_v_long_square  trough_v_ramp  \
# 0          ...                      -56.531254     -56.812502
# 1          ...                      -48.843754     -50.093753
# 2          ...                      -49.531250     -49.968753
# 3          ...                      -46.156254     -49.218753
# 4          ...                      -52.093750     -57.614586
#
#    trough_v_short_square  upstroke_downstroke_ratio_long_square  \
# 0             -69.306253                               3.904747
# 1             -67.416669                               4.231335
# 2             -75.656255                               2.154281
# 3             -66.318753                               2.026000
# 4             -73.337500                               4.208485
#
#    upstroke_downstroke_ratio_ramp  upstroke_downstroke_ratio_short_square  \
# 0                        4.131130                                3.899439
# 1                        4.299535                                3.939083
# 2                        1.486651                                2.400687
# 3                        1.827572                                1.818158
# 4                        4.274151                                4.096372
#
#    vm_for_sag      vrest  transgenic_line        reporter_status
# 0  -85.156258 -68.233376     Cux2-CreERT2  cre reporter negative
# 1  -78.593750 -66.085068  Chrna2-Cre_OE25  cre reporter positive
# 2  -87.156250 -75.141449             None         not applicable
# 3  -82.406250 -65.503044     Sst-IRES-Cre  cre reporter positive
# 4  -99.093758 -72.174675     Cux2-CreERT2  cre reporter positive
#
# [5 rows x 57 columns]

# %%
ef_df['hemisphere'] = pd.Series(hemisphere, index = ef_df.index)
ef_df.head()
# Out:
#    adaptation     avg_isi  electrode_0_pa  f_i_curve_slope  \
# 0    0.093021   81.498750       -6.184375         0.205899
# 1    0.064384   76.283333       26.135000         0.195247
# 2         NaN         NaN       -4.600001         0.055443
# 3    0.048709  118.397143      -90.575616         0.307589
# 4    0.042215   81.394545       13.653750         0.162729
#
#    fast_trough_t_long_square  fast_trough_t_ramp  fast_trough_t_short_square  \
# 0                   1.126905            2.768700                    1.025464
# 1                   1.102660            4.005247                    1.024873
# 2                   1.104820            9.092507                    1.025024
# 3                   1.069770            7.203945                    1.024593
# 4                   1.089750            2.336427                    1.027302
#
#    fast_trough_v_long_square  fast_trough_v_ramp  fast_trough_v_short_square  \
# 0                 -51.187504          -50.328125                  -55.312504
# 1                 -48.718750          -49.875001                  -51.500004
# 2                 -48.093750          -49.541669                  -50.312503
# 3                 -45.968754          -49.093754                  -53.800002
# 4                 -48.906250          -51.083335                  -55.800002
#
#       ...      trough_v_ramp  trough_v_short_square  \
# 0     ...         -56.812502             -69.306253
# 1     ...         -50.093753             -67.416669
# 2     ...         -49.968753             -75.656255
# 3     ...         -49.218753             -66.318753
# 4     ...         -57.614586             -73.337500
#
#    upstroke_downstroke_ratio_long_square  upstroke_downstroke_ratio_ramp  \
# 0                               3.904747                        4.131130
# 1                               4.231335                        4.299535
# 2                               2.154281                        1.486651
# 3                               2.026000                        1.827572
# 4                               4.208485                        4.274151
#
#    upstroke_downstroke_ratio_short_square  vm_for_sag      vrest  \
# 0                                3.899439  -85.156258 -68.233376
# 1                                3.939083  -78.593750 -66.085068
# 2                                2.400687  -87.156250 -75.141449
# 3                                1.818158  -82.406250 -65.503044
# 4                                4.096372  -99.093758 -72.174675
#
#    transgenic_line        reporter_status  hemisphere
# 0     Cux2-CreERT2  cre reporter negative        left
# 1  Chrna2-Cre_OE25  cre reporter positive        left
# 2             None         not applicable        left
# 3     Sst-IRES-Cre  cre reporter positive       right
# 4     Cux2-CreERT2  cre reporter positive       right
#
# [5 rows x 58 columns]

# %%
ef_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1337 entries, 0 to 1336
# Data columns (total 58 columns):
# adaptation                                1096 non-null float64
# avg_isi                                   1216 non-null float64
# electrode_0_pa                            1329 non-null float64
# f_i_curve_slope                           1337 non-null float64
# fast_trough_t_long_square                 1337 non-null float64
# fast_trough_t_ramp                        1301 non-null float64
# fast_trough_t_short_square                1337 non-null float64
# fast_trough_v_long_square                 1337 non-null float64
# fast_trough_v_ramp                        1301 non-null float64
# fast_trough_v_short_square                1337 non-null float64
# has_burst                                 1337 non-null bool
# has_delay                                 1337 non-null bool
# has_pause                                 1337 non-null bool
# id                                        1337 non-null int64
# input_resistance_mohm                     1337 non-null float64
# latency                                   1337 non-null float64
# peak_t_long_square                        1337 non-null float64
# peak_t_ramp                               1301 non-null float64
# peak_t_short_square                       1337 non-null float64
# peak_v_long_square                        1337 non-null float64
# peak_v_ramp                               1301 non-null float64
# peak_v_short_square                       1337 non-null float64
# rheobase_sweep_id                         1337 non-null int64
# rheobase_sweep_number                     1337 non-null int64
# ri                                        1337 non-null float64
# sag                                       1337 non-null float64
# seal_gohm                                 1337 non-null float64
# slow_trough_t_long_square                 877 non-null float64
# slow_trough_t_ramp                        897 non-null float64
# slow_trough_t_short_square                1049 non-null float64
# slow_trough_v_long_square                 877 non-null float64
# slow_trough_v_ramp                        897 non-null float64
# slow_trough_v_short_square                1049 non-null float64
# specimen_id                               1337 non-null int64
# threshold_i_long_square                   1337 non-null float64
# threshold_i_ramp                          1301 non-null float64
# threshold_i_short_square                  1337 non-null float64
# threshold_t_long_square                   1337 non-null float64
# threshold_t_ramp                          1301 non-null float64
# threshold_t_short_square                  1337 non-null float64
# threshold_v_long_square                   1337 non-null float64
# threshold_v_ramp                          1301 non-null float64
# threshold_v_short_square                  1337 non-null float64
# thumbnail_sweep_id                        1337 non-null int64
# trough_t_long_square                      1337 non-null float64
# trough_t_ramp                             1301 non-null float64
# trough_t_short_square                     1337 non-null float64
# trough_v_long_square                      1337 non-null float64
# trough_v_ramp                             1301 non-null float64
# trough_v_short_square                     1337 non-null float64
# upstroke_downstroke_ratio_long_square     1337 non-null float64
# upstroke_downstroke_ratio_ramp            1301 non-null float64
# upstroke_downstroke_ratio_short_square    1337 non-null float64
# vm_for_sag                                1337 non-null float64
# vrest                                     1337 non-null float64
# transgenic_line                           1058 non-null object
# reporter_status                           1316 non-null object
# hemisphere                                1337 non-null object
# dtypes: bool(3), float64(47), int64(5), object(3)
# memory usage: 578.5+ KB

# %%
no_need_features = ['electrode_0_pa', 'has_burst', 'has_delay', 'has_pause', 'id', 
                    'rheobase_sweep_id', 'rheobase_sweep_number', 'seal_gohm', 'specimen_id',
                   'thumbnail_sweep_id', 'slow_trough_t_long_square', 'slow_trough_t_ramp', 
                   'slow_trough_v_long_square', 'slow_trough_v_ramp']

# %%
ef_df_extracted = ef_df.drop(no_need_features, axis=1)

# %%
ef_df_extracted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1337 entries, 0 to 1336
# Data columns (total 44 columns):
# adaptation                                1096 non-null float64
# avg_isi                                   1216 non-null float64
# f_i_curve_slope                           1337 non-null float64
# fast_trough_t_long_square                 1337 non-null float64
# fast_trough_t_ramp                        1301 non-null float64
# fast_trough_t_short_square                1337 non-null float64
# fast_trough_v_long_square                 1337 non-null float64
# fast_trough_v_ramp                        1301 non-null float64
# fast_trough_v_short_square                1337 non-null float64
# input_resistance_mohm                     1337 non-null float64
# latency                                   1337 non-null float64
# peak_t_long_square                        1337 non-null float64
# peak_t_ramp                               1301 non-null float64
# peak_t_short_square                       1337 non-null float64
# peak_v_long_square                        1337 non-null float64
# peak_v_ramp                               1301 non-null float64
# peak_v_short_square                       1337 non-null float64
# ri                                        1337 non-null float64
# sag                                       1337 non-null float64
# slow_trough_t_short_square                1049 non-null float64
# slow_trough_v_short_square                1049 non-null float64
# threshold_i_long_square                   1337 non-null float64
# threshold_i_ramp                          1301 non-null float64
# threshold_i_short_square                  1337 non-null float64
# threshold_t_long_square                   1337 non-null float64
# threshold_t_ramp                          1301 non-null float64
# threshold_t_short_square                  1337 non-null float64
# threshold_v_long_square                   1337 non-null float64
# threshold_v_ramp                          1301 non-null float64
# threshold_v_short_square                  1337 non-null float64
# trough_t_long_square                      1337 non-null float64
# trough_t_ramp                             1301 non-null float64
# trough_t_short_square                     1337 non-null float64
# trough_v_long_square                      1337 non-null float64
# trough_v_ramp                             1301 non-null float64
# trough_v_short_square                     1337 non-null float64
# upstroke_downstroke_ratio_long_square     1337 non-null float64
# upstroke_downstroke_ratio_ramp            1301 non-null float64
# upstroke_downstroke_ratio_short_square    1337 non-null float64
# vm_for_sag                                1337 non-null float64
# vrest                                     1337 non-null float64
# transgenic_line                           1058 non-null object
# reporter_status                           1316 non-null object
# hemisphere                                1337 non-null object
# dtypes: float64(41), object(3)
# memory usage: 459.7+ KB

# %%
ef_df_extracted['height'] = ef_df_extracted['peak_v_short_square'] -ef_df_extracted['fast_trough_v_short_square']
ef_df_extracted['firing_rate'] = (1/ef_df_extracted['avg_isi'])*1000

# %%
ef_df_extracted.head()
# Out:
#    adaptation     avg_isi  f_i_curve_slope  fast_trough_t_long_square  \
# 0    0.093021   81.498750         0.205899                   1.126905
# 1    0.064384   76.283333         0.195247                   1.102660
# 2         NaN         NaN         0.055443                   1.104820
# 3    0.048709  118.397143         0.307589                   1.069770
# 4    0.042215   81.394545         0.162729                   1.089750
#
#    fast_trough_t_ramp  fast_trough_t_short_square  fast_trough_v_long_square  \
# 0            2.768700                    1.025464                 -51.187504
# 1            4.005247                    1.024873                 -48.718750
# 2            9.092507                    1.025024                 -48.093750
# 3            7.203945                    1.024593                 -45.968754
# 4            2.336427                    1.027302                 -48.906250
#
#    fast_trough_v_ramp  fast_trough_v_short_square  input_resistance_mohm  \
# 0          -50.328125                  -55.312504             180.243392
# 1          -49.875001                  -51.500004             134.676480
# 2          -49.541669                  -50.312503             189.801760
# 3          -49.093754                  -53.800002             164.745728
# 4          -51.083335                  -55.800002             289.122080
#
#       ...       upstroke_downstroke_ratio_long_square  \
# 0     ...                                    3.904747
# 1     ...                                    4.231335
# 2     ...                                    2.154281
# 3     ...                                    2.026000
# 4     ...                                    4.208485
#
#    upstroke_downstroke_ratio_ramp  upstroke_downstroke_ratio_short_square  \
# 0                        4.131130                                3.899439
# 1                        4.299535                                3.939083
# 2                        1.486651                                2.400687
# 3                        1.827572                                1.818158
# 4                        4.274151                                4.096372
#
#    vm_for_sag      vrest  transgenic_line        reporter_status  hemisphere  \
# 0  -85.156258 -68.233376     Cux2-CreERT2  cre reporter negative        left
# 1  -78.593750 -66.085068  Chrna2-Cre_OE25  cre reporter positive        left
# 2  -87.156250 -75.141449             None         not applicable        left
# 3  -82.406250 -65.503044     Sst-IRES-Cre  cre reporter positive       right
# 4  -99.093758 -72.174675     Cux2-CreERT2  cre reporter positive       right
#
#        height  firing_rate
# 0   98.450006    12.270127
# 1  105.031258    13.109023
# 2   89.918754          NaN
# 3   81.287503     8.446150
# 4   84.887503    12.285836
#
# [5 rows x 46 columns]

# %%
def dis_EI(cre_line): # labelling for excitory vs inbihitory cre line
    output = []
    for item in cre_line:
        if (item == 'Pvalb-IRES-Cre' or item == 'Sst-IRES-Cre' or
            item == 'Htr3a-Cre_NO152' or item == 'Vip-IRES-Cre' or
            item == 'Gad2-IRES-Cre' or item == 'Chat-IRES-Cre-neo' or
            item == 'Chrna2-Cre_OE25' or item == 'Nkx2-1-CreERT2'):
                output = output + ['Inhibitory']
        else:
            output = output + ['Excitatory']
    return output
ef_df_extracted['binary_neuron'] = pd.DataFrame(dis_EI(ef_df_extracted['transgenic_line']))

# %%
ef_df_extracted.tail()
# Out:
#       adaptation     avg_isi  f_i_curve_slope  fast_trough_t_long_square  \
# 1332    0.033096  127.260000         0.141466                    1.30392
# 1333    0.021331   55.857500         0.126190                    1.14522
# 1334    0.047917  112.735625         0.079324                    1.16643
# 1335    0.028293   84.403636         0.122825                    1.13298
# 1336         NaN    6.260000         0.010326                    1.13888
#
#       fast_trough_t_ramp  fast_trough_t_short_square  \
# 1332            2.453470                    1.027433
# 1333            4.860593                    1.024965
# 1334            7.605778                    1.025228
# 1335            7.115233                    1.025576
# 1336           15.949200                    1.025120
#
#       fast_trough_v_long_square  fast_trough_v_ramp  \
# 1332                 -51.062504          -51.468752
# 1333                 -46.093750          -47.020835
# 1334                 -57.000004          -57.572918
# 1335                 -44.125000          -48.250003
# 1336                 -52.125004          -58.218753
#
#       fast_trough_v_short_square  input_resistance_mohm      ...        \
# 1332                  -51.916668             152.173744      ...
# 1333                  -48.492190             251.630560      ...
# 1334                  -58.762502              66.813688      ...
# 1335                  -51.337503             165.862832      ...
# 1336                  -55.331253              62.743816      ...
#
#       upstroke_downstroke_ratio_ramp  upstroke_downstroke_ratio_short_square  \
# 1332                        4.406138                                4.282831
# 1333                        3.710321                                3.378424
# 1334                        3.010267                                3.396610
# 1335                        3.481667                                4.269691
# 1336                        3.705363                                3.634396
#
#       vm_for_sag      vrest  transgenic_line        reporter_status  \
# 1332  -88.031258 -63.121693             None         not applicable
# 1333  -96.781250 -78.259277   Scnn1a-Tg3-Cre  cre reporter positive
# 1334  -89.718750 -73.232635             None         not applicable
# 1335  -93.000000 -79.386765   Rorb-IRES2-Cre  cre reporter positive
# 1336  -78.687508 -72.151871             None         not applicable
#
#       hemisphere      height  firing_rate  binary_neuron
# 1332        left  102.000005     7.857929     Excitatory
# 1333        left   89.195316    17.902699     Excitatory
# 1334        left   99.037505     8.870311     Excitatory
# 1335        left   92.687505    11.847831     Excitatory
# 1336       right  106.300006   159.744409     Excitatory
#
# [5 rows x 47 columns]

# %%
ef_df_cre = ef_df_extracted[ef_df_extracted['reporter_status']=='cre reporter positive']
len(ef_df_cre)
# Out:
# 969

# %%
pd.DataFrame(ef_df_cre['transgenic_line'].value_counts())
# Out:
#                    transgenic_line
# Pvalb-IRES-Cre                 142
# Rorb-IRES2-Cre                 120
# Sst-IRES-Cre                   111
# Htr3a-Cre_NO152                 89
# Cux2-CreERT2                    73
# Rbp4-Cre_KL100                  72
# Nr5a1-Cre                       69
# Scnn1a-Tg3-Cre                  60
# Ntsr1-Cre_GN220                 48
# Scnn1a-Tg2-Cre                  36
# Chrna2-Cre_OE25                 31
# Ctgf-T2A-dgCre                  26
# Nkx2-1-CreERT2                  23
# Vip-IRES-Cre                    20
# Chat-IRES-Cre-neo               20
# Ndnf-IRES2-dgCre                15
# Gad2-IRES-Cre                   11
# Slc17a6-IRES-Cre                 3

# %%
pd.DataFrame(ef_df_cre['binary_neuron'].value_counts())
# Out:
#             binary_neuron
# Excitatory            522
# Inhibitory            447

# %%
ef_df_cre.to_csv('ephys_data_cre_hemisphere.csv', index = False)

# %%
ef_df_extracted.to_csv('ephys_data_hemisphere.csv', index = False)

# %% [markdown]
# * ephys_data_cre.csv
# - missing hemisphere col, in further data process using these data.
# - hemisphere feature was tested for pilot.
